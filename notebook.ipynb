# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# # 设置项目根目录 (请确保 "My Drive" 是您云盘的正确名称)
# PROJECT_ROOT="/content/drive/MyDrive/project/ot_spx_vix"
#
# # --- 1. 创建主文件夹 ---
# mkdir -p "$PROJECT_ROOT/data"
# mkdir -p "$PROJECT_ROOT/src"
# mkdir -p "$PROJECT_ROOT/notebooks"
#
# # --- 2. 创建 src 目录下的 Python 文件 ---
# # 使用 'touch' 命令创建空文件
# touch "$PROJECT_ROOT/src/simulate_heston.py"
# touch "$PROJECT_ROOT/src/pricing_pde.py"
# touch "$PROJECT_ROOT/src/hjb_solver.py"
# touch "$PROJECT_ROOT/src/optimizer.py"
# touch "$PROJECT_ROOT/src/reference_iter.py"
# touch "$PROJECT_ROOT/src/utils.py"
# touch "$PROJECT_ROOT/src/visualize.py"
# touch "$PROJECT_ROOT/src/__init__.py"  # 添加 __init__.py 使其成为一个包(package)
#
# # --- 3. 创建根目录下的占位文件 ---
# touch "$PROJECT_ROOT/README.md"
# touch "$PROJECT_ROOT/requirements.txt"
#
# # --- 4. （可选）在 notebooks 文件夹中创建一个示例 notebook ---
# # 注意：Colab 不能直接 'touch' 一个 .ipynb 文件。
# # 您需要手动在 Google Drive 界面中，进入 ot_spx_vix/notebooks/ 文件夹，
# # 右键 -> "更多" -> "Google Colaboratory" 来创建一个新的 notebook。
# # 或者，您可以先创建一个空文件，然后在 Colab 中打开它：
# touch "$PROJECT_ROOT/notebooks/main_experiment.ipynb"
#
# # --- 5. 验证结构 ---
# echo "项目结构创建完成:"
# ls -R "$PROJECT_ROOT"
# Out:
# 项目结构创建完成:
# /content/drive/MyDrive/project/ot_spx_vix:
# data
# notebook.ipynb
# notebooks
# README.md
# requirements.txt
# src
#
# /content/drive/MyDrive/project/ot_spx_vix/data:
#
# /content/drive/MyDrive/project/ot_spx_vix/notebooks:
# main_experiment.ipynb
#
# /content/drive/MyDrive/project/ot_spx_vix/src:
# hjb_solver.py
# __init__.py
# optimizer.py
# pricing_pde.py
# reference_iter.py
# simulate_heston.py
# utils.py
# visualize.py
